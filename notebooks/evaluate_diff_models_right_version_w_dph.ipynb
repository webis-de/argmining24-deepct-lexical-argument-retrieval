# %%
import pandas as pd
import numpy as np
import pyterrier_deepct
import pyterrier as pt
if not pt.started():
  pt.init(boot_packages=["com.github.terrierteam:terrier-prf:-SNAPSHOT"])
# Out:
# PyTerrier 0.8.0 has loaded Terrier 5.6 (built by craigmacdonald on 2021-09-17 13:27)

# %%
from xml.etree import ElementTree
tree = ElementTree.parse('/workspace/src/evaluate_targers/topics2020.xml')
data = tree.getroot()
titles = []
title_ids = []
nums = []
for topic in data:
    titles.append(topic.find('title').text.lower()[:-1])
    num = topic.find('number').text
    nums.append(num)
tree = ElementTree.parse('/workspace/src/evaluate_targers/topics.xml')
data = tree.getroot()    
for topic in data:
    titles.append(topic.find('title').text.lower()[:-1])
    num = topic.find('number').text
    nums.append(num)
topics = pd.DataFrame()
topics['qid'] = nums
topics['query'] = titles

qrels_path=("/workspace/src/evaluate_targers/qrels.qrels")
qrels = pt.io.read_qrels(qrels_path)

docnos = qrels.docno

# %%
import os
rootdir = "/mnt/ceph/storage/data-in-progress/data-teaching/theses/wstud-thesis-hollatz/DeepCT_indexes/"

for subdir, dirs, files in os.walk(rootdir):
    for file in files:
        if(file == 'data.properties'):
            print(subdir)
            path = subdir + '/'+ file
            indexref = pt.IndexRef.of(path)
            index = pt.IndexFactory.of(indexref)
            dph = pt.BatchRetrieve(index, wmodel="DPH")
            dph_rm3 = (pt.BatchRetrieve(indexref, wmodel="DPH") >> 
            pt.rewrite.RM3(indexref) >> 
            pt.BatchRetrieve(indexref, wmodel="DPH"))
            bm25_rm3 = (pt.BatchRetrieve(indexref, wmodel="BM25") >> 
            pt.rewrite.RM3(indexref) >> 
            pt.BatchRetrieve(indexref, wmodel="BM25"))
            tf_idf = pt.BatchRetrieve(index, wmodel="TF_IDF")
            bm25 = pt.BatchRetrieve(index, wmodel="BM25")
            dlm = pt.BatchRetrieve(index, wmodel="DirichletLM")
            dlm_rm3 = (pt.BatchRetrieve(indexref, wmodel="DirichletLM") >> 
            pt.rewrite.RM3(indexref) >> 
            pt.BatchRetrieve(indexref, wmodel="DirichletLM"))
            models = [dph, dph_rm3, tf_idf, bm25_rm3, bm25, dlm, dlm_rm3]
            print(pt.Experiment(models, topics, qrels, eval_metrics=["ndcg_cut_5", "bpref", "ndcg_cut_25"]))
# Out:
# /mnt/ceph/storage/data-in-progress/data-teaching/theses/wstud-thesis-hollatz/DeepCT_indexes/conclusionspd_index
#                                                 name  ndcg_cut_5     bpref  \
# 0                                            BR(DPH)    0.315636  0.644521
# 1  Compose(Compose(BR(DPH), <pyterrier.rewrite.RM...    0.321356  0.667382
# 2                                         BR(TF_IDF)    0.486396  0.724771
# 3  Compose(Compose(BR(BM25), <pyterrier.rewrite.R...    0.481536  0.749372
# 4                                           BR(BM25)    0.482386  0.725052
# 5                                    BR(DirichletLM)    0.605145  0.726433
# 6  Compose(Compose(BR(DirichletLM), <pyterrier.re...    0.525739  0.702217
#
#    ndcg_cut_25
# 0     0.306881
# 1     0.316702
# 2     0.446201
# 3     0.448463
# 4     0.445090
# 5     0.524329
# 6     0.387855
# /mnt/ceph/storage/data-in-progress/data-teaching/theses/wstud-thesis-hollatz/DeepCT_indexes/pool_topicspd_index
#                                                 name  ndcg_cut_5     bpref  \
# 0                                            BR(DPH)    0.365402  0.652921
# 1  Compose(Compose(BR(DPH), <pyterrier.rewrite.RM...    0.338825  0.681465
# 2                                         BR(TF_IDF)    0.493342  0.720428
# 3  Compose(Compose(BR(BM25), <pyterrier.rewrite.R...    0.510960  0.752424
# 4                                           BR(BM25)    0.490716  0.719048
# 5                                    BR(DirichletLM)    0.618747  0.718117
# 6  Compose(Compose(BR(DirichletLM), <pyterrier.re...    0.516398  0.700186
#
#    ndcg_cut_25
# 0     0.317258
# 1     0.331995
# 2     0.451531
# 3     0.453957
# 4     0.448634
# 5     0.522950
# 6     0.389506
# /mnt/ceph/storage/data-in-progress/data-teaching/theses/wstud-thesis-hollatz/DeepCT_indexes/topicspd_index
#                                                 name  ndcg_cut_5     bpref  \
# 0                                            BR(DPH)    0.334037  0.640059
# 1  Compose(Compose(BR(DPH), <pyterrier.rewrite.RM...    0.297611  0.658038
# 2                                         BR(TF_IDF)    0.464064  0.715897
# 3  Compose(Compose(BR(BM25), <pyterrier.rewrite.R...    0.488692  0.744116
# 4                                           BR(BM25)    0.465107  0.716173
# 5                                    BR(DirichletLM)    0.591248  0.717413
# 6  Compose(Compose(BR(DirichletLM), <pyterrier.re...    0.461109  0.694420
#
#    ndcg_cut_25
# 0     0.299982
# 1     0.310971
# 2     0.437728
# 3     0.448610
# 4     0.437603
# 5     0.522979
# 6     0.371671
# /mnt/ceph/storage/data-in-progress/data-teaching/theses/wstud-thesis-hollatz/DeepCT_indexes/topics_conclusionpd_index
#                                                 name  ndcg_cut_5     bpref  \
# 0                                            BR(DPH)    0.354162  0.646091
# 1  Compose(Compose(BR(DPH), <pyterrier.rewrite.RM...    0.347515  0.670104
# 2                                         BR(TF_IDF)    0.462663  0.724294
# 3  Compose(Compose(BR(BM25), <pyterrier.rewrite.R...    0.486420  0.745781
# 4                                           BR(BM25)    0.464399  0.724515
# 5                                    BR(DirichletLM)    0.600549  0.721682
# 6  Compose(Compose(BR(DirichletLM), <pyterrier.re...    0.493671  0.696586
#
#    ndcg_cut_25
# 0     0.308182
# 1     0.321872
# 2     0.431531
# 3     0.452565
# 4     0.427242
# 5     0.523576
# 6     0.378607
# /mnt/ceph/storage/data-in-progress/data-teaching/theses/wstud-thesis-hollatz/DeepCT_indexes/topics_conclusions_leakage/pd_index
#                                                 name  ndcg_cut_5     bpref  \
# 0                                            BR(DPH)    0.266234  0.629321
# 1  Compose(Compose(BR(DPH), <pyterrier.rewrite.RM...    0.276747  0.658249
# 2                                         BR(TF_IDF)    0.484367  0.722231
# 3  Compose(Compose(BR(BM25), <pyterrier.rewrite.R...    0.502976  0.743944
# 4                                           BR(BM25)    0.478129  0.722275
# 5                                    BR(DirichletLM)    0.605714  0.723567
# 6  Compose(Compose(BR(DirichletLM), <pyterrier.re...    0.456901  0.700962
#
#    ndcg_cut_25
# 0     0.261199
# 1     0.268538
# 2     0.454774
# 3     0.451632
# 4     0.453024
# 5     0.540352
# 6     0.369942
# /mnt/ceph/storage/data-in-progress/data-teaching/theses/wstud-thesis-hollatz/DeepCT_indexes/topics_leakage/pd_index
#                                                 name  ndcg_cut_5     bpref  \
# 0                                            BR(DPH)    0.256130  0.625723
# 1  Compose(Compose(BR(DPH), <pyterrier.rewrite.RM...    0.257843  0.651605
# 2                                         BR(TF_IDF)    0.475159  0.725966
# 3  Compose(Compose(BR(BM25), <pyterrier.rewrite.R...    0.471246  0.748293
# 4                                           BR(BM25)    0.476256  0.726038
# 5                                    BR(DirichletLM)    0.600911  0.726751
# 6  Compose(Compose(BR(DirichletLM), <pyterrier.re...    0.508109  0.701657
#
#    ndcg_cut_25
# 0     0.246020
# 1     0.261661
# 2     0.444679
# 3     0.434845
# 4     0.444556
# 5     0.528058
# 6     0.373689
# /mnt/ceph/storage/data-in-progress/data-teaching/theses/wstud-thesis-hollatz/DeepCT_indexes/pools_topics_conclusionspd_index
#                                                 name  ndcg_cut_5     bpref  \
# 0                                            BR(DPH)    0.358054  0.654742
# 1  Compose(Compose(BR(DPH), <pyterrier.rewrite.RM...    0.355171  0.679081
# 2                                         BR(TF_IDF)    0.489948  0.722736
# 3  Compose(Compose(BR(BM25), <pyterrier.rewrite.R...    0.519656  0.745469
# 4                                           BR(BM25)    0.491433  0.722995
# 5                                    BR(DirichletLM)    0.640963  0.724230
# 6  Compose(Compose(BR(DirichletLM), <pyterrier.re...    0.539089  0.697211
#
#    ndcg_cut_25
# 0     0.318496
# 1     0.338338
# 2     0.453105
# 3     0.453916
# 4     0.452863
# 5     0.532831
# 6     0.407824
# /mnt/ceph/storage/data-in-progress/data-teaching/theses/wstud-thesis-hollatz/DeepCT_indexes/conclusions_leakage/pd_index
#                                                 name  ndcg_cut_5     bpref  \
# 0                                            BR(DPH)    0.317877  0.623721
# 1  Compose(Compose(BR(DPH), <pyterrier.rewrite.RM...    0.312784  0.647790
# 2                                         BR(TF_IDF)    0.512157  0.725210
# 3  Compose(Compose(BR(BM25), <pyterrier.rewrite.R...    0.500818  0.743472
# 4                                           BR(BM25)    0.516987  0.724458
# 5                                    BR(DirichletLM)    0.610826  0.724681
# 6  Compose(Compose(BR(DirichletLM), <pyterrier.re...    0.439660  0.684251
#
#    ndcg_cut_25
# 0     0.270754
# 1     0.291245
# 2     0.453472
# 3     0.452056
# 4     0.454317
# 5     0.522746
# 6     0.347309
# /mnt/ceph/storage/data-in-progress/data-teaching/theses/wstud-thesis-hollatz/DeepCT_indexes/pools_conclusionspd_index
#                                                 name  ndcg_cut_5     bpref  \
# 0                                            BR(DPH)    0.338051  0.647767
# 1  Compose(Compose(BR(DPH), <pyterrier.rewrite.RM...    0.329581  0.671578
# 2                                         BR(TF_IDF)    0.495457  0.718172
# 3  Compose(Compose(BR(BM25), <pyterrier.rewrite.R...    0.529849  0.741359
# 4                                           BR(BM25)    0.496191  0.718457
# 5                                    BR(DirichletLM)    0.616240  0.715116
# 6  Compose(Compose(BR(DirichletLM), <pyterrier.re...    0.491506  0.677977
#
#    ndcg_cut_25
# 0     0.305319
# 1     0.321836
# 2     0.445096
# 3     0.458074
# 4     0.444897
# 5     0.520169
# 6     0.375547

# %%
import os
rootdir = "/mnt/ceph/storage/data-in-progress/data-teaching/theses/wstud-thesis-hollatz/DeepCT_indexes/"

for subdir, dirs, files in os.walk(rootdir):
    for file in files:
        if(file == 'data.properties'):
            print('\n' + subdir)
            path = subdir + '/'+ file
            indexref = pt.IndexRef.of(path)
            index = pt.IndexFactory.of(indexref)
            dph = pt.BatchRetrieve(index, wmodel="DPH")
            dph_rm3 = (pt.BatchRetrieve(indexref, wmodel="DPH") >> 
            pt.rewrite.RM3(indexref) >> 
            pt.BatchRetrieve(indexref, wmodel="DPH"))
            bm25_rm3 = (pt.BatchRetrieve(indexref, wmodel="BM25") >> 
            pt.rewrite.RM3(indexref) >> 
            pt.BatchRetrieve(indexref, wmodel="BM25"))
            tf_idf = pt.BatchRetrieve(index, wmodel="TF_IDF")
            bm25 = pt.BatchRetrieve(index, wmodel="BM25")
            dlm = pt.BatchRetrieve(index, wmodel="DirichletLM")
            dlm_rm3 = (pt.BatchRetrieve(indexref, wmodel="DirichletLM") >> 
            pt.rewrite.RM3(indexref) >> 
            pt.BatchRetrieve(indexref, wmodel="DirichletLM"))
            models = [dph, dph_rm3, tf_idf, bm25_rm3, bm25, dlm, dlm_rm3]
        
            for model in models:
                res= model.transform(topics)
                res_copy = res[res['docno'].isin(docnos)].copy()
                print(f'model : {model}, res: {pt.Utils.evaluate(res_copy,qrels,metrics=["ndcg_cut_5", "bpref", "ndcg_cut_25"])}')
# Out:
# /mnt/ceph/storage/data-in-progress/data-teaching/theses/wstud-thesis-hollatz/DeepCT_indexes/conclusionspd_index
# model : BR(DPH), res: {'ndcg_cut_5': 0.6195559003690524, 'bpref': 0.6445214979422608, 'ndcg_cut_25': 0.6412295985168942}
# model : Compose(Compose(BR(DPH), <pyterrier.rewrite.RM3 object at 0x7fe6dd3ed190>), BR(DPH)), res: {'ndcg_cut_5': 0.6400572193920301, 'bpref': 0.667382205137545, 'ndcg_cut_25': 0.6544399199256083}
# model : BR(TF_IDF), res: {'ndcg_cut_5': 0.6283797590144036, 'bpref': 0.7247708473797921, 'ndcg_cut_25': 0.6753707122077693}
# model : Compose(Compose(BR(BM25), <pyterrier.rewrite.RM3 object at 0x7fe6dd3ed050>), BR(BM25)), res: {'ndcg_cut_5': 0.6704911407713139, 'bpref': 0.7493722124385017, 'ndcg_cut_25': 0.7055810321214193}
# model : BR(BM25), res: {'ndcg_cut_5': 0.629094689978407, 'bpref': 0.7250523093453518, 'ndcg_cut_25': 0.6765302738349726}
# model : BR(DirichletLM), res: {'ndcg_cut_5': 0.7111994374419488, 'bpref': 0.7264330830118617, 'ndcg_cut_25': 0.7229021475536862}
# model : Compose(Compose(BR(DirichletLM), <pyterrier.rewrite.RM3 object at 0x7fe6dd663ed0>), BR(DirichletLM)), res: {'ndcg_cut_5': 0.7016733022048054, 'bpref': 0.702216595811059, 'ndcg_cut_25': 0.6842281926611758}
#
# /mnt/ceph/storage/data-in-progress/data-teaching/theses/wstud-thesis-hollatz/DeepCT_indexes/pool_topicspd_index
# model : BR(DPH), res: {'ndcg_cut_5': 0.6350159416400514, 'bpref': 0.6529205015109898, 'ndcg_cut_25': 0.6561835379814245}
# model : Compose(Compose(BR(DPH), <pyterrier.rewrite.RM3 object at 0x7fe6dd3f4610>), BR(DPH)), res: {'ndcg_cut_5': 0.6556582320257757, 'bpref': 0.6814652418034125, 'ndcg_cut_25': 0.6711074271083026}
# model : BR(TF_IDF), res: {'ndcg_cut_5': 0.642341683143697, 'bpref': 0.7204280566738166, 'ndcg_cut_25': 0.6857458417060763}
# model : Compose(Compose(BR(BM25), <pyterrier.rewrite.RM3 object at 0x7fe6dd3ed350>), BR(BM25)), res: {'ndcg_cut_5': 0.6858085904068897, 'bpref': 0.7524243750930804, 'ndcg_cut_25': 0.7155137400853717}
# model : BR(BM25), res: {'ndcg_cut_5': 0.6393443031490417, 'bpref': 0.7190479895900244, 'ndcg_cut_25': 0.6821182756312493}
# model : BR(DirichletLM), res: {'ndcg_cut_5': 0.7063696387713557, 'bpref': 0.7181172056274511, 'ndcg_cut_25': 0.7200118026790665}
# model : Compose(Compose(BR(DirichletLM), <pyterrier.rewrite.RM3 object at 0x7fe6dd659a90>), BR(DirichletLM)), res: {'ndcg_cut_5': 0.6711489415216131, 'bpref': 0.7001859279145797, 'ndcg_cut_25': 0.675224747160787}
#
# /mnt/ceph/storage/data-in-progress/data-teaching/theses/wstud-thesis-hollatz/DeepCT_indexes/topicspd_index
# model : BR(DPH), res: {'ndcg_cut_5': 0.6098943467641064, 'bpref': 0.6400592601598657, 'ndcg_cut_25': 0.6338613876915017}
# model : Compose(Compose(BR(DPH), <pyterrier.rewrite.RM3 object at 0x7fe6dd3f4410>), BR(DPH)), res: {'ndcg_cut_5': 0.6112035050300286, 'bpref': 0.6580376289844636, 'ndcg_cut_25': 0.6546844442121302}
# model : BR(TF_IDF), res: {'ndcg_cut_5': 0.6409956931566105, 'bpref': 0.7158968690415939, 'ndcg_cut_25': 0.6834214040150587}
# model : Compose(Compose(BR(BM25), <pyterrier.rewrite.RM3 object at 0x7fe6dd419f90>), BR(BM25)), res: {'ndcg_cut_5': 0.6872701510108606, 'bpref': 0.7441159089391892, 'ndcg_cut_25': 0.713118206707489}
# model : BR(BM25), res: {'ndcg_cut_5': 0.6400701100321647, 'bpref': 0.7161733032069233, 'ndcg_cut_25': 0.6837273619734789}
# model : BR(DirichletLM), res: {'ndcg_cut_5': 0.7120821460794182, 'bpref': 0.7174126728235154, 'ndcg_cut_25': 0.7198017558071734}
# model : Compose(Compose(BR(DirichletLM), <pyterrier.rewrite.RM3 object at 0x7fe6dc4300d0>), BR(DirichletLM)), res: {'ndcg_cut_5': 0.6625066807540021, 'bpref': 0.6944203800997444, 'ndcg_cut_25': 0.6762363877742604}
#
# /mnt/ceph/storage/data-in-progress/data-teaching/theses/wstud-thesis-hollatz/DeepCT_indexes/topics_conclusionpd_index
# model : BR(DPH), res: {'ndcg_cut_5': 0.6145136958277112, 'bpref': 0.6460913692542369, 'ndcg_cut_25': 0.6391866828356129}
# model : Compose(Compose(BR(DPH), <pyterrier.rewrite.RM3 object at 0x7fe6dd659850>), BR(DPH)), res: {'ndcg_cut_5': 0.6459457707922641, 'bpref': 0.6701044468122356, 'ndcg_cut_25': 0.6699765152945747}
# model : BR(TF_IDF), res: {'ndcg_cut_5': 0.6400720886643866, 'bpref': 0.7242943268980462, 'ndcg_cut_25': 0.681433282113226}
# model : Compose(Compose(BR(BM25), <pyterrier.rewrite.RM3 object at 0x7fe6dd663d90>), BR(BM25)), res: {'ndcg_cut_5': 0.6953813883122281, 'bpref': 0.7457805412921279, 'ndcg_cut_25': 0.7174066506436556}
# model : BR(BM25), res: {'ndcg_cut_5': 0.641619256967451, 'bpref': 0.7245149879304652, 'ndcg_cut_25': 0.6809854511173838}
# model : BR(DirichletLM), res: {'ndcg_cut_5': 0.7281212264052805, 'bpref': 0.7216817459984961, 'ndcg_cut_25': 0.7331215339001784}
# model : Compose(Compose(BR(DirichletLM), <pyterrier.rewrite.RM3 object at 0x7fe6dd9818d0>), BR(DirichletLM)), res: {'ndcg_cut_5': 0.6882742491343911, 'bpref': 0.6965860015561904, 'ndcg_cut_25': 0.6868997006083454}
#
# /mnt/ceph/storage/data-in-progress/data-teaching/theses/wstud-thesis-hollatz/DeepCT_indexes/topics_conclusions_leakage/pd_index
# model : BR(DPH), res: {'ndcg_cut_5': 0.5862265433198148, 'bpref': 0.6293214067708977, 'ndcg_cut_25': 0.6306394383878853}
# model : Compose(Compose(BR(DPH), <pyterrier.rewrite.RM3 object at 0x7fe6dd3f4810>), BR(DPH)), res: {'ndcg_cut_5': 0.5764848996853739, 'bpref': 0.6582493356544699, 'ndcg_cut_25': 0.6484385680067368}
# model : BR(TF_IDF), res: {'ndcg_cut_5': 0.6461647685042127, 'bpref': 0.7222308581063366, 'ndcg_cut_25': 0.6896237863882954}
# model : Compose(Compose(BR(BM25), <pyterrier.rewrite.RM3 object at 0x7fe673e4e6d0>), BR(BM25)), res: {'ndcg_cut_5': 0.6921326040150655, 'bpref': 0.7439441864390762, 'ndcg_cut_25': 0.7143941893826762}
# model : BR(BM25), res: {'ndcg_cut_5': 0.6477192113648966, 'bpref': 0.7222752819843672, 'ndcg_cut_25': 0.6881784573431523}
# model : BR(DirichletLM), res: {'ndcg_cut_5': 0.7296209217234144, 'bpref': 0.7235667530221975, 'ndcg_cut_25': 0.7341943692236991}
# model : Compose(Compose(BR(DirichletLM), <pyterrier.rewrite.RM3 object at 0x7fe6dc430250>), BR(DirichletLM)), res: {'ndcg_cut_5': 0.665946354295464, 'bpref': 0.7009623404697739, 'ndcg_cut_25': 0.6870805448754359}
#
# /mnt/ceph/storage/data-in-progress/data-teaching/theses/wstud-thesis-hollatz/DeepCT_indexes/topics_leakage/pd_index
# model : BR(DPH), res: {'ndcg_cut_5': 0.548727732036567, 'bpref': 0.6257229216001745, 'ndcg_cut_25': 0.6100626882555715}
# model : Compose(Compose(BR(DPH), <pyterrier.rewrite.RM3 object at 0x7fe6dd659bd0>), BR(DPH)), res: {'ndcg_cut_5': 0.5731355229701295, 'bpref': 0.6516048987182131, 'ndcg_cut_25': 0.6344889774931672}
# model : BR(TF_IDF), res: {'ndcg_cut_5': 0.6465386502974776, 'bpref': 0.7259658278924052, 'ndcg_cut_25': 0.6908980526943503}
# model : Compose(Compose(BR(BM25), <pyterrier.rewrite.RM3 object at 0x7fe673e6b150>), BR(BM25)), res: {'ndcg_cut_5': 0.6915248444030242, 'bpref': 0.7482933395069611, 'ndcg_cut_25': 0.7219873619090654}
# model : BR(BM25), res: {'ndcg_cut_5': 0.6486557744049192, 'bpref': 0.7260375106659882, 'ndcg_cut_25': 0.691438832226641}
# model : BR(DirichletLM), res: {'ndcg_cut_5': 0.7179362344375068, 'bpref': 0.7267506669643486, 'ndcg_cut_25': 0.72782765355362}
# model : Compose(Compose(BR(DirichletLM), <pyterrier.rewrite.RM3 object at 0x7fe6dd663f90>), BR(DirichletLM)), res: {'ndcg_cut_5': 0.7021631661703828, 'bpref': 0.7016572582168409, 'ndcg_cut_25': 0.6905472932493038}
#
# /mnt/ceph/storage/data-in-progress/data-teaching/theses/wstud-thesis-hollatz/DeepCT_indexes/pools_topics_conclusionspd_index
# model : BR(DPH), res: {'ndcg_cut_5': 0.6477857410353238, 'bpref': 0.6547416008659894, 'ndcg_cut_25': 0.6579160207827094}
# model : Compose(Compose(BR(DPH), <pyterrier.rewrite.RM3 object at 0x7fe6dd419c90>), BR(DPH)), res: {'ndcg_cut_5': 0.6666782089649762, 'bpref': 0.6790814117364179, 'ndcg_cut_25': 0.680751078025771}
# model : BR(TF_IDF), res: {'ndcg_cut_5': 0.6394608493163715, 'bpref': 0.7227362009170157, 'ndcg_cut_25': 0.6852050161056318}
# model : Compose(Compose(BR(BM25), <pyterrier.rewrite.RM3 object at 0x7fe6dd3f2450>), BR(BM25)), res: {'ndcg_cut_5': 0.6947773997028946, 'bpref': 0.7454693044413575, 'ndcg_cut_25': 0.7080889487469816}
# model : BR(BM25), res: {'ndcg_cut_5': 0.6411503883269666, 'bpref': 0.7229949896170438, 'ndcg_cut_25': 0.6858383244261228}
# model : BR(DirichletLM), res: {'ndcg_cut_5': 0.7260830966001861, 'bpref': 0.7242295125287797, 'ndcg_cut_25': 0.7264345172113333}
# model : Compose(Compose(BR(DirichletLM), <pyterrier.rewrite.RM3 object at 0x7fe672981610>), BR(DirichletLM)), res: {'ndcg_cut_5': 0.6882073485436841, 'bpref': 0.6972114751645626, 'ndcg_cut_25': 0.690913163187647}
#
# /mnt/ceph/storage/data-in-progress/data-teaching/theses/wstud-thesis-hollatz/DeepCT_indexes/conclusions_leakage/pd_index
# model : BR(DPH), res: {'ndcg_cut_5': 0.5805778549885019, 'bpref': 0.6237207579083259, 'ndcg_cut_25': 0.612998295227225}
# model : Compose(Compose(BR(DPH), <pyterrier.rewrite.RM3 object at 0x7fe6dd3ed0d0>), BR(DPH)), res: {'ndcg_cut_5': 0.6108996998303491, 'bpref': 0.6477898272689451, 'ndcg_cut_25': 0.641937092297454}
# model : BR(TF_IDF), res: {'ndcg_cut_5': 0.6501033958698862, 'bpref': 0.7252101679090649, 'ndcg_cut_25': 0.6904114695618232}
# model : Compose(Compose(BR(BM25), <pyterrier.rewrite.RM3 object at 0x7fe6dd419150>), BR(BM25)), res: {'ndcg_cut_5': 0.6799940881595761, 'bpref': 0.7434717295961208, 'ndcg_cut_25': 0.7061188591831441}
# model : BR(BM25), res: {'ndcg_cut_5': 0.6517929348804813, 'bpref': 0.7244583181419657, 'ndcg_cut_25': 0.6903664870323414}
# model : BR(DirichletLM), res: {'ndcg_cut_5': 0.7114985233928445, 'bpref': 0.7246813161238035, 'ndcg_cut_25': 0.7293758781324672}
# model : Compose(Compose(BR(DirichletLM), <pyterrier.rewrite.RM3 object at 0x7fe6ddbdcd90>), BR(DirichletLM)), res: {'ndcg_cut_5': 0.6647225686450782, 'bpref': 0.6842514484103499, 'ndcg_cut_25': 0.6644962518697882}
#
# /mnt/ceph/storage/data-in-progress/data-teaching/theses/wstud-thesis-hollatz/DeepCT_indexes/pools_conclusionspd_index
# model : BR(DPH), res: {'ndcg_cut_5': 0.6334109419769975, 'bpref': 0.6477672025885272, 'ndcg_cut_25': 0.6536684513191363}
# model : Compose(Compose(BR(DPH), <pyterrier.rewrite.RM3 object at 0x7fe6dd3f4050>), BR(DPH)), res: {'ndcg_cut_5': 0.677790256750906, 'bpref': 0.6715777490919037, 'ndcg_cut_25': 0.6725211236561742}
# model : BR(TF_IDF), res: {'ndcg_cut_5': 0.6333197257693065, 'bpref': 0.7181722713274137, 'ndcg_cut_25': 0.6836271024321523}
# model : Compose(Compose(BR(BM25), <pyterrier.rewrite.RM3 object at 0x7fe6dd6597d0>), BR(BM25)), res: {'ndcg_cut_5': 0.6898757920015669, 'bpref': 0.7413585827151293, 'ndcg_cut_25': 0.7097538925157519}
# model : BR(BM25), res: {'ndcg_cut_5': 0.6269722244086872, 'bpref': 0.7184568902315778, 'ndcg_cut_25': 0.68290163157776}
# model : BR(DirichletLM), res: {'ndcg_cut_5': 0.6953746829896988, 'bpref': 0.71511629342613, 'ndcg_cut_25': 0.720695782903226}
# model : Compose(Compose(BR(DirichletLM), <pyterrier.rewrite.RM3 object at 0x7fe6dc4307d0>), BR(DirichletLM)), res: {'ndcg_cut_5': 0.6576111661745732, 'bpref': 0.6779765549848245, 'ndcg_cut_25': 0.6619134732076772}
